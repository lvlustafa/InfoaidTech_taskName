# %%
import random

def number_guessing_game():
    print("Welcome to the Number Guessing Game!")
    name = input("Enter your name: ")
    print(f"Hello, {name}! I have selected a random number between 1 and 100.")

    play_game = True

    while play_game:
        secret_number = random.randint(1, 100)
        attempts = 0

        while attempts < 10:
            guess = int(input("Enter your guess: "))
            attempts += 1

            if guess == secret_number:
                print(f"Congratulations, {name}! You guessed the number {secret_number} correctly in {attempts} attempts.")
                break
            elif guess < secret_number:
                print("Too low! Try again.")
            else:
                print("Too high! Try again.")

        if attempts == 10:
            print(f"Game over, {name}! The correct number was {secret_number}.")

        play_again = input("Do you want to play again? (yes/no): ").lower()
        play_game = play_again == "yes"

    print("Thanks for playing!")

if __name__ == "__main__":
    number_guessing_game()
# Out:
# Welcome to the Number Guessing Game!
# Enter your name: Mustafa
# Hello, Mustafa! I have selected a random number between 1 and 100.
# Enter your guess: 7
# Too low! Try again.
# Enter your guess: 6
# Too low! Try again.
# Enter your guess: 7
# Too low! Try again.
# Enter your guess: 6
# Too low! Try again.
# Enter your guess: 34
# Too low! Try again.
# Enter your guess: 77
# Too low! Try again.
# Enter your guess: 90
# Too low! Try again.
# Enter your guess: 00
# Too low! Try again.
# Enter your guess: 99
# Congratulations, Mustafa! You guessed the number 99 correctly in 9 attempts.
# Do you want to play again? (yes/no): yes
# Enter your guess: 3
# Too low! Try again.
# Enter your guess: 4
# Too low! Try again.
# Enter your guess: 99
# Too high! Try again.
# Enter your guess: 66
# Too high! Try again.
# Enter your guess: 55
# Too low! Try again.
# Enter your guess: 57
# Too low! Try again.
# Enter your guess: 60
# Too low! Try again.
# Enter your guess: 62
# ...
